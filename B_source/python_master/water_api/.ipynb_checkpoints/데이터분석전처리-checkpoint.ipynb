# %%
from modules import connection as cn ,apiurl as au
from modules.dataprocess import DataProcess
from bs4 import BeautifulSoup
import math
import sys
#year=sys.argv[1]
#if(len(sys.argv!=1)):
#    print("1개더 쓰세요")
#    sys.exit()
year=2019
    
#지역정보를 가져옴
api_url=au.crop_kwater_url(1)
print(api_url)
soup=cn.getSoup(api_url)
dp=DataProcess()
sido=[]
for item in soup.find_all("sido"):
    sido.append(item.text)
sido=['충남', '전남']
    
#지반종류 가져옴
api_url=au.crop_kwater_url(2)
soup=cn.getSoup(api_url)
wellnum=[]
for item in soup.find_all("code"):
    wellnum.append(item.text)

#년도 정보를 가져옴
#api_url=au.crop_kwater_url(4)
#soup=cn.getSoup(api_url)
#year=[]
#for item in soup.find_all("yyyy"):
#    year.append(item.text)
    
#상세 지역정보를 가져옴
api_url=au.crop_kwater_url(3,sido,wellnum)
jewon={}
for key, value in api_url.items():
    soup=cn.getSoup(key)
    for item in soup.find_all("wnumno"):
        wnumno=item.text
        jewon[wnumno]=value


#최종 지하수 정보       
api_url=au.crop_kwater_url(5,year,jewon)
data=[]
dp=DataProcess()
for api_url1 in api_url:
    print(api_url1)
    soup=cn.getSoup(api_url1)
    for item in soup.find_all("item"):
        row={}
        for ele in item:
            row.update({ele.name:ele.text.split(" ")[0]})
        data.append(row)
    if len(data)!=0:
        dp.setDataList(data)
    else:
        print("no data to fetch!")
    dp.writeToCsv()

# %%
from modules import connection as cn ,apiurl as au
from modules.dataprocess import DataProcess
from bs4 import BeautifulSoup
import math
import sys
#year=sys.argv[1]
#if(len(sys.argv!=1)):
#    print("1개더 쓰세요")
#    sys.exit()
year=2019
    
#지역정보를 가져옴
api_url=au.crop_kwater_url(1)
print(api_url)
soup=cn.getSoup(api_url)
dp=DataProcess()
sido=[]
for item in soup.find_all("sido"):
    sido.append(item.text)
sido=['충남', '전남']
    
#지반종류 가져옴
api_url=au.crop_kwater_url(2)
soup=cn.getSoup(api_url)
wellnum=[]
for item in soup.find_all("code"):
    wellnum.append(item.text)

#년도 정보를 가져옴
#api_url=au.crop_kwater_url(4)
#soup=cn.getSoup(api_url)
#year=[]
#for item in soup.find_all("yyyy"):
#    year.append(item.text)
    
#상세 지역정보를 가져옴
api_url=au.crop_kwater_url(3,sido,wellnum)
jewon={}
print(jewon)
# for key, value in api_url.items():
#     soup=cn.getSoup(key)
#     for item in soup.find_all("wnumno"):
#         wnumno=item.text
#         jewon[wnumno]=value

# %%
#from modules import connection as cn ,apiurl as au
#from modules.dataprocess import DataProcess
#from bs4 import BeautifulSoup
#import math
#sido=['경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주']
#wellnum=['1', '2']
#year=['2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996']
jewon={'2225': ['%EA%B2%BD%EA%B8%B0', '1'], '9875': ['%EA%B2%BD%EA%B8%B0', '1'], '95506': ['%EA%B2%BD%EA%B8%B0', '1'], '87235': ['%EA%B2%BD%EA%B8%B0', '1'], '612006': ['%EA%B2%BD%EA%B8%B0', '1'], '65008': ['%EA%B2%BD%EA%B8%B0', '1'], '65010': ['%EA%B2%BD%EA%B8%B0',
], '11781': ['%EA%B2%BD%EB%82%A8', '2'], '73550': ['%EA%B2%BD%EB%82%A8', '2'], '625362': ['%EA%B2%BD%EB%82%A8', '2'], '65606': ['%EA%B2%BD%EB%82%A8', '2'], '82049': ['%EA%B2%BD%EB%82%A8', '2'], '65049': ['%EA%B2%BD%EB%82%A8', '2'], '11788': ['%EA%B2%BD%EB%82%A8', '2'], '95534': ['%EC%A0%9C%EC%A3%BC', '1'], '95535': ['%EC%A0%9C%EC%A3%BC', '1'], '95537': ['%EC%A0%9C%EC%A3%BC', '1'], '95536': ['%EC%A0%9C%EC%A3%BC', '1']}

# %%
import urllib.parse
gennum_list={}
for k,v in jewon.items():
    gennum_list[k]=urllib.parse.unquote_plus(v[0])
print(gennum_list)
# Out:
# {'2225': '경기', '9875': '경기', '95506': '경기', '87235': '경기', '612006': '경기', '65008': '경기', '65010': '경기', '603271': '경기', '601739': '경기', '65586': '경기', '11738': '경기', '615509': '경기', '87236': '경기', '615514': '경기', '84013': '경기', '9871': '경기', '65052': '경기', '84001': '경기', '95502': '경기', '718001': '경기', '612017': '경기', '9872': '경기', '9873': '경기', '84015': '경기', '65021': '경기', '84016': '경기', '87237': '경기', '82000': '경기', '65063': '경기', '65065': '경기', '95507': '경기', '9876': '경기', '87238': '경기', '9877': '경기', '87239': '경기', '622080': '경기', '637541': '경기', '87241': '경기', '87242': '경기', '11740': '경기', '612001': '경기', '65609': '경기', '11744': '경기', '95503': '경기', '95504': '경기', '65036': '경기', '84017': '경기', '87244': '경기', '65046': '경기', '95509': '경기', '87245': '경기', '11742': '경기', '405429': '경기', '95511': '경기', '65047': '경기', '87246': '경기', '622085': '경기', '82002': '경기', '87247': '경기', '84019': '경기', '2224': '경기', '65009': '경기', '11739': '경기', '84014': '경기', '65053': '경기', '84002': '경기', '98
# ...

# %%
print(sido)
print(jewon)

# %%
from modules import connection as cn ,apiurl as au
from modules.dataprocess import DataProcess
from bs4 import BeautifulSoup
import math
import sys
#year=sys.argv[1]
#if(len(sys.argv!=1)):
#    print("1개더 쓰세요")
#    sys.exit()
year=2019
    
#지역정보를 가져옴
api_url=au.crop_kwater_url(1)
print(api_url)
soup=cn.getSoup(api_url)
dp=DataProcess()
sido=[]
for item in soup.find_all("sido"):
    sido.append(item.text)
sido=['충남', '전남']
    
#지반종류 가져옴
api_url=au.crop_kwater_url(2)
soup=cn.getSoup(api_url)
wellnum=[]
for item in soup.find_all("code"):
    wellnum.append(item.text)

    

api_url=au.crop_kwater_url(3,sido,wellnum)
print(api_url)
jewon={}

# %%
jewon={}
for key, value in api_url.items():
    soup=cn.getSoup(key)
    for item in soup.find_all("wnumno"):
        wnumno=item.text
        jewon[wnumno]=value

# %%
A8', '2'], '73526': ['%EC%A0%84%EB%82%A8', '2'], '11777': ['%EC%A0%84%EB%82%A8', '2'], '65051': ['%EC%A0%84%EB%82%A8', '2'], '11774': ['%EC%A0%84%EB%82%A8', '2'], '9897': ['%EC%A0%84%EB%82%A8', '2'], '6752': ['%EC%A0%84%EB%82%A8', '2'], '65060': ['%EC%A0%84%EB%82%A8', '2'], '615520': ['%EC%A0%84%EB%82%A8', '2'], '514307': ['%EC%A0%84%EB%82%A8', '2'], '73529': ['%EC%A0%84%EB%82%A8', '2'], '82038': ['%EC%A0%84%EB%82%A8', '2'], '11779': ['%EC%A0%84%EB%82%A8', '2'], '65038': ['%EC%A0%84%EB%82%A8', '2'], '9900': ['%EC%A0%84%EB%82%A8', '2'], '514309': ['%EC%A0%84%EB%82%A8', '2'], '9903': ['%EC%A0%84%EB%82%A8', '2'], '73531': ['%EC%A0%84%EB%82%A8', '2']}

# %%
api_url=au.crop_kwater_url(5,year,jewon)
num=api_url.index('http://opendata.kwater.or.kr/openapi-data/service/pubd/underGroundWater/waterQuality/list?&gennum=73528&stdt=1996&eddt=2015&sido=%EC%A0%84%EB%82%A8&wellnum=1&numOfRows=10&serviceKey=jAkk5tTEPGKz1Zs6w%2FbGGpkPBCc%2BrrJcw2QI9LfcrYD77m2cQJWDgzZP14xOPIOpZQWJm2P2nC2ZsaacfYxcLw%3D%3D&pageNo=1')
print(num)
print(len(api_url))
#여기서부터 돌리면 됨
api_url=api_url[102:]

#102번

# %%
import pandas as pd


df=pd.DataFrame(data)
df.to_csv("C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\result_water_final2019-06-08 19-49-17.csv")

# %%
df

# %%
import math

totalcount=32
print(totalcount/numofrows)
pageMaxNum=math.ceil(totalcount/numofrows)
print(pageMaxNum)

# %%
print(rep_)

# %%
#최종 지하수 정보       
api_url=au.crop_kwater_url(5,year,jewon)
api_url=api_url[102:]
data=[]
dp=DataProcess()
for api_url1 in api_url:
    print(api_url1)
    soup=cn.getSoup(api_url1)
    for item in soup.find_all("item"):
        row={}
        for ele in item:
            row.update({ele.name:ele.text.split(" ")[0]})
        data.append(row)
    if len(data)!=0:
        dp.setDataList(data)
    else:
        print("no data to fetch!")
    dp.writeToCsv()

# %%
from modules import connection as cn ,apiurl as au
from modules.dataprocess import DataProcess
from bs4 import BeautifulSoup
import math
import sys
import pandas as pd
import glob

# 인자값받아서 yesr를 지정하는 옵션
# year=sys.argv[1] 
# if(len(sys.argv!=1)):
#     print("1개더 쓰세요")
#     sys.exit()
year=2019
    
#지역정보를 가져옴
api_url=au.crop_kwater_url(1)
print(api_url)
soup=cn.getSoup(api_url)
dp=DataProcess()
sido=[]
for item in soup.find_all("sido"):
    sido.append(item.text)
sido=['충남', '전남']
    
#지반종류 가져옴
api_url=au.crop_kwater_url(2)
soup=cn.getSoup(api_url)
wellnum=[]
for item in soup.find_all("code"):
    wellnum.append(item.text)

#년도 정보를 가져옴
#api_url=au.crop_kwater_url(4)
#soup=cn.getSoup(api_url)
#year=[]
#for item in soup.find_all("yyyy"):
#    year.append(item.text)
    
#상세 지역정보를 가져옴
api_url=au.crop_kwater_url(3,sido,wellnum)
jewon={}
for key, value in api_url.items():
    soup=cn.getSoup(key)
    for item in soup.find_all("wnumno"):
        wnumno=item.text
        jewon[wnumno]=value


#최종 지하수 정보       
api_url=au.crop_kwater_url(5,year,jewon)
data=[]
dp=DataProcess()
for api_url1 in api_url:
    print(api_url1)
    soup=cn.getSoup(api_url1)
    for item in soup.find_all("item"):
        row={}
        for ele in item:
            row.update({ele.name:ele.text.split(" ")[0]})
        data.append(row)
    if len(data)!=0:
        dp.setDataList(data)
    else:
        print("no data to fetch!")
    dp.writeToCsv()

#폴더에 있는 모든 주소를 불러옴
df=pd.DataFrame(data)
path = "C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\*"
file_list = glob.glob(path)
file_list_csv = [file for file in file_list if file.endswith(".csv")]

#데이터를 하나로 만듬
df1=[]
for file_name in file_list_csv:
    df2=pd.read_csv(file_name, encoding='utf-8')
    df1.append(df2)
data=pd.concat(df1, ignore_index=True)
data=data.drop(data.columns[[0]], axis='columns')
data=data.drop_duplicates()

#컬럼을 만들어줌
data["year"]=data['testymd'].str[:4]
data["month"]=data['testymd'].str[5:7]
data["si"]=data['obsvname'].str[:2]
data['do']=[gennum_list[str(x)] for x in data['gennum']]

#만들어준 컬럼의 위치를 변경
#cols=data.columns.tolist()
#cols=cols[-4:]+cols[:-4]
#data=data[cols]

#저장하기
data.to_csv('C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\final_result2.csv')

# %%
from modules import connection as cn ,apiurl as au
from modules.dataprocess import DataProcess
from bs4 import BeautifulSoup
import math
import sys
import pandas as pd
import glob

# %%
data

# %%
#폴더에 있는 모든 주소를 불러옴
df=pd.DataFrame(data)
path = "C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\*"
file_list = glob.glob(path)
file_list_csv = [file for file in file_list if file.endswith(".csv")]

#데이터를 하나로 만듬
df1=[]
for file_name in file_list_csv:
    df2=pd.read_csv(file_name, encoding='utf-8')
    df1.append(df2)
data=pd.concat(df1, ignore_index=True)
data=data.drop(data.columns[[0]], axis='columns')
data=data.drop_duplicates()

#컬럼을 만들어줌
data["year"]=data['testymd'].str[:4]
data["month"]=data['testymd'].str[5:7]
data["si"]=data['obsvname'].str[:2]
data['do']=[gennum_list[str(x)] for x in data['gennum']]

#만들어준 컬럼의 위치를 변경
cols=data.columns.tolist()
cols=cols[-4:]+cols[:-4]
data=data[cols]

#저장하기
data.to_csv('C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\final_result312123112.csv')

# %%
#폴더에 있는 모든 주소를 불러옴
#df=pd.DataFrame(data)
path = "C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\*"
file_list = glob.glob(path)
file_list_csv = [file for file in file_list if file.endswith(".csv")]
print(file_list_csv)
# Out:
# ['C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-07.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-08.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-09.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-10.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-11.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-12.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-13.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-14.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-15.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final2019-06-08 19-49-16.csv', 'C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\1result_water_final
# ...

# %%
#데이터를 하나로 만듬
df1=[]
for file_name in file_list_csv:
    df2=pd.read_csv(file_name, encoding='utf-8')
    df1.append(df2)
data=pd.concat(df1, ignore_index=True)
data=data.drop(data.columns[[0]], axis='columns')
data=data.drop_duplicates()

# %%
#컬럼을 만들어줌
data["year"]=data['testymd'].str[:4]
data["month"]=data['testymd'].str[5:7]
data["si"]=data['obsvname'].str[:2]
data['do']=[gennum_list[str(x)] for x in data['gennum']]

# %%
#만들어준 컬럼의 위치를 변경
cols=data.columns.tolist()
cols=cols[-4:]+cols[:-4]
data=data[cols]

# %%
data['year_month']=data['year']+'_'+data['month']
data.set_index("year_month")
data1=data[data["si"]=='천안']
data2=data[data["si"]=='나주']
data1.set_index("watnum")
data2.set_index("watnum")
data2=data2.drop_duplicates(['year_month'], keep='first')
data1=data1.drop_duplicates(['year_month'], keep='first')
data1 = data1.sort_values(["year_month"], ascending=[False])
data2 = data2.sort_values(["year_month"], ascending=[False])

data1
# Out:
#       year month  si  do     bac  benzene  bidno bigo   cd     cl  ...   ph  \
# 1023  2015    11  천안  충남     2.0      0.0     28   적합  0.0   12.7  ...  8.0
# 1013  2015    09  천안  충남    43.0      0.0     26  부적합  0.0  265.7  ...  6.4
# 1014  2015    06  천안  충남    23.0      0.0     25  부적합  0.0  481.7  ...  6.2
# 1015  2014    10  천안  충남     9.0      0.0     24   적합  0.0   91.1  ...  6.8
# 1026  2014    06  천안  충남     0.0      0.0     25   적합  0.0   11.2  ...  7.1
# 1016  2014    05  천안  충남     5.0      0.0     23  부적합  0.0  323.2  ...  6.6
# 1027  2013    11  천안  충남     3.0      NaN     24   적합  NaN   37.2  ...  6.9
# 1017  2013    10  천안  충남    22.0      NaN     22   적합  NaN    3.4  ...  6.4
# 1034  2012    11  천안  충남    57.0      NaN      9  부적합  NaN   31.0  ...  9.1
# 1018  2012    10  천안  충남     0.0      NaN     21   적합  NaN   30.7  ...  6.6
# 1019  2012    06  천안  충남     0.0      NaN     20   적합  NaN   55.3  ...  6.7
# ...

# %%
data1.to_csv('C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\ddd\\천안_1.csv')

# %%
y_m_l=[str(x)+'_'+str(y).zfill(2)  for x in range(1990,2019) for y in range(1,13)]
print(y_m_l)
# Out:
# ['1990_01', '1990_02', '1990_03', '1990_04', '1990_05', '1990_06', '1990_07', '1990_08', '1990_09', '1990_10', '1990_11', '1990_12', '1991_01', '1991_02', '1991_03', '1991_04', '1991_05', '1991_06', '1991_07', '1991_08', '1991_09', '1991_10', '1991_11', '1991_12', '1992_01', '1992_02', '1992_03', '1992_04', '1992_05', '1992_06', '1992_07', '1992_08', '1992_09', '1992_10', '1992_11', '1992_12', '1993_01', '1993_02', '1993_03', '1993_04', '1993_05', '1993_06', '1993_07', '1993_08', '1993_09', '1993_10', '1993_11', '1993_12', '1994_01', '1994_02', '1994_03', '1994_04', '1994_05', '1994_06', '1994_07', '1994_08', '1994_09', '1994_10', '1994_11', '1994_12', '1995_01', '1995_02', '1995_03', '1995_04', '1995_05', '1995_06', '1995_07', '1995_08', '1995_09', '1995_10', '1995_11', '1995_12', '1996_01', '1996_02', '1996_03', '1996_04', '1996_05', '1996_06', '1996_07', '1996_08', '1996_09', '1996_10', '1996_11', '1996_12', '1997_01', '1997_02', '1997_03', '1997_04', '1997_05', '1997_06', '1997_0
# ...

# %%
year_month_list=[]
year_month_list=data1["year_month"]

# %%
y_m_l
#data['do']=[gennum_list[str(x)] for x in data['year_month']]
for x in y_m_l:
    if x not in list(data1["year_month"]):
        data1.loc[x, 'year_month'] = x
    if x in list(data1["year_month"]):
        data1.loc[x] = data1[(data1["year_month"]==x)].values[0]

# %%
data1=data1.drop_duplicates(['year_month'], keep='last')

# %%
data_columns=data1.columns
colum=['bac', 'cl', 'no3n', 'ph']
for dcol in data_columns:
    if dcol not in colum:
        data1=data1.drop([dcol], axis=1)
data1
# Out:
#          bac  cl  no3n  ph
# 1990_01  NaN NaN   NaN NaN
# 1990_02  NaN NaN   NaN NaN
# 1990_03  NaN NaN   NaN NaN
# 1990_04  NaN NaN   NaN NaN
# 1990_05  NaN NaN   NaN NaN
# 1990_06  NaN NaN   NaN NaN
# 1990_07  NaN NaN   NaN NaN
# 1990_08  NaN NaN   NaN NaN
# 1990_09  NaN NaN   NaN NaN
# 1990_10  NaN NaN   NaN NaN
# 1990_11  NaN NaN   NaN NaN
# 1990_12  NaN NaN   NaN NaN
# 1991_01  NaN NaN   NaN NaN
# 1991_02  NaN NaN   NaN NaN
# 1991_03  NaN NaN   NaN NaN
# 1991_04  NaN NaN   NaN NaN
# 1991_05  NaN NaN   NaN NaN
# 1991_06  NaN NaN   NaN NaN
# 1991_07  NaN NaN   NaN NaN
# 1991_08  NaN NaN   NaN NaN
# 1991_09  NaN NaN   NaN NaN
# 1991_10  NaN NaN   NaN NaN
# 1991_11  NaN NaN   NaN NaN
# 1991_12  NaN NaN   NaN NaN
# 1992_01  NaN NaN   NaN NaN
# 1992_02  NaN NaN   NaN NaN
# 1992_03  NaN NaN   NaN NaN
# 1992_04  NaN NaN   NaN NaN
# 1992_05  NaN NaN   NaN NaN
# 1992_06  NaN NaN   NaN NaN
# ...      ...  ..   ...  ..
# 2016_07  NaN NaN   NaN NaN
# 2016_08  NaN NaN   NaN NaN
# ...

# %%
data1=data1.interpolate(method ='linear', limit_direction ='forward') 
data1
# Out:
#          bac    cl  no3n   ph
# 1990_01  NaN   NaN   NaN  NaN
# 1990_02  NaN   NaN   NaN  NaN
# 1990_03  NaN   NaN   NaN  NaN
# 1990_04  NaN   NaN   NaN  NaN
# 1990_05  NaN   NaN   NaN  NaN
# 1990_06  NaN   NaN   NaN  NaN
# 1990_07  NaN   NaN   NaN  NaN
# 1990_08  NaN   NaN   NaN  NaN
# 1990_09  NaN   NaN   NaN  NaN
# 1990_10  NaN   NaN   NaN  NaN
# 1990_11  NaN   NaN   NaN  NaN
# 1990_12  NaN   NaN   NaN  NaN
# 1991_01  NaN   NaN   NaN  NaN
# 1991_02  NaN   NaN   NaN  NaN
# 1991_03  NaN   NaN   NaN  NaN
# 1991_04  NaN   NaN   NaN  NaN
# 1991_05  NaN   NaN   NaN  NaN
# 1991_06  NaN   NaN   NaN  NaN
# 1991_07  NaN   NaN   NaN  NaN
# 1991_08  NaN   NaN   NaN  NaN
# 1991_09  NaN   NaN   NaN  NaN
# 1991_10  NaN   NaN   NaN  NaN
# 1991_11  NaN   NaN   NaN  NaN
# 1991_12  NaN   NaN   NaN  NaN
# 1992_01  NaN   NaN   NaN  NaN
# 1992_02  NaN   NaN   NaN  NaN
# 1992_03  NaN   NaN   NaN  NaN
# 1992_04  NaN   NaN   NaN  NaN
# 1992_05  NaN   NaN   NaN  NaN
# 1992_06  NaN   NaN   NaN  NaN
# ...

# %%
ddd=data1[data_columns[0]].max()
print(ddd)
si=int(len(data1))
for dc in data_columns:
    print(dc)
    try:
        max_d=int(data1[dc].max())
        print(max_d)
        min_d=int(data1[dc].min())
        print(min_d)
        #if max_d==1 or min_d==0 :
        if ((max_d==1 and min_d==0)or (max_d==0 and min_d==0)or (max_d==1 and min_d==1)):
            print("둘다")
        else:
            m_m=(max_d-min_d)/100
            print(m_m)
            #random1=np.random.randint(-m_m, m_m, size=si)+np.random.randn(si)
            #random1=(np.random.rand(int(len(data1)))*(max_d-min_d)+min_d)/100
            random1=(np.random.rand(si)*2-1)*m_m
            print("asdf"+data1[dc])
            data1[dc]=data1[dc]-random1
    except TypeError:
        pass
    

#data1['cl'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-382bf94bc0d6> in <module>
# ----> 1 ddd=data1[data_columns[0]].max()
#       2 print(ddd)
#       3 si=int(len(data1))
#       4 for dc in data_columns:
#       5     print(dc)
#
# NameError: name 'data1' is not defined

# %%
max=data1['cl'].max()
min=float(data1['cl'].min())

# %%
data1

# %%
import numpy as np

print(data1['p'])

# %%
import matplotlib.pyplot as plt
plt.bar(data1.index,data1['bac'])
plt.rcParams["figure.figsize"] = (30,30)

plt.show()

# %%
#저장하기
data1.to_csv('C:\\Users\\kosta\\Downloads\\파이널api사용\\102번에서\\final_result_천안_nan처리후.csv')
